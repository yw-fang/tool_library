# %%
import pandas as pd
df = pd.read_csv('cryspy_rslt_energy_asc',names=['cryspy_id', 'Gen', 'Spg_num','Spg_sym','Spg_num_opt',
                                                 'Spg_sym_opt', 'E_eV_atom', 'Magmom', 'Opt'], header=None, delim_whitespace=True,skiprows=[0])
# min_enthalpy = min(df['enthalpy']);

# %%
df
# Out:
#      cryspy_id  Gen  Spg_num Spg_sym  Spg_num_opt Spg_sym_opt  E_eV_atom  \
# 0          299    6       26  Pmc2_1            1          P1  -0.329042
# 1          481   10        1      P1            2         P-1  -0.284395
# 2          580   12        2     P-1            2         P-1  -0.283273
# 3          538   11        1      P1            2         P-1  -0.283151
# 4          634   13        2     P-1            2         P-1  -0.282361
# ..         ...  ...      ...     ...          ...         ...        ...
# 745        595   12      203    Fd-3          227       Fd-3m   1.410374
# 746        340    7      227   Fd-3m          227       Fd-3m   1.410376
# 747          0    1      224   Pn-3m          224       Pn-3m   1.412310
# 748        600   13        1      P1            1          P1   3.492614
# 749        599   12       79      I4            0        None        NaN
#
#      Magmom      Opt
# 0       NaN  not_yet
# 1       NaN  not_yet
# 2       NaN  not_yet
# ...

# %%
df.sort_values('E_eV_atom').head(50)
# Out:
#     cryspy_id  Gen  Spg_num Spg_sym  Spg_num_opt Spg_sym_opt  E_eV_atom  \
# 0         299    6       26  Pmc2_1            1          P1  -0.329042
# 1         481   10        1      P1            2         P-1  -0.284395
# 2         580   12        2     P-1            2         P-1  -0.283273
# 3         538   11        1      P1            2         P-1  -0.283151
# 4         634   13        2     P-1            2         P-1  -0.282361
# 5         688   14        2     P-1            2         P-1  -0.281997
# 6         105    3        1      P1            1          P1  -0.281807
# 7         635   13        2     P-1            2         P-1  -0.280889
# 8          85    2        1      P1            1          P1  -0.280692
# 9         434    9        1      P1            1          P1  -0.274023
# 10        677   14        1      P1            2         P-1  -0.273906
# 11        639   13        2     P-1            2         P-1  -0.273893
# ...
